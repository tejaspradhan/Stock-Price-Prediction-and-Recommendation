# %%
# %matplotlib inline
import pandas as pd
import mplfinance as mpf

# %%
data = pd.read_csv('Cleaned_Stock_Data.csv')

# %%
data = data.head(1259)   # for one stock

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1259 non-null   int64
#  1   date        1259 non-null   object
#  2   open        1259 non-null   float64
#  3   high        1259 non-null   float64
#  4   low         1259 non-null   float64
#  5   close       1259 non-null   float64
#  6   volume      1259 non-null   int64
#  7   Name        1259 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 78.8+ KB

# %%
data.date = pd.to_datetime(data.date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1259 non-null   int64
#  1   date        1259 non-null   datetime64[ns]
#  2   open        1259 non-null   float64
#  3   high        1259 non-null   float64
#  4   low         1259 non-null   float64
#  5   close       1259 non-null   float64
#  6   volume      1259 non-null   int64
#  7   Name        1259 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 78.8+ KB

# %%
data = data.set_index('date')

# %%
data.head()
# Out:
#             Unnamed: 0   open   high    low  close    volume Name
# date
# 2013-02-08           0  15.07  15.12  14.63  14.75   8407500  AAL
# 2013-02-11           1  14.89  15.01  14.26  14.46   8882000  AAL
# 2013-02-12           2  14.45  14.51  14.10  14.27   8126000  AAL
# 2013-02-13           3  14.30  14.94  14.25  14.66  10259500  AAL
# 2013-02-14           4  14.94  14.96  13.16  13.99  31879900  AAL

# %%
mpf.plot(data)

# %%
mpf.plot(data,type='line',volume=True)

# %%
mpf.plot(data['2017-11'],volume=True)

# %%
mpf.plot(data['2017-11'],type='candle',volume=True)

# %%
mpf.plot(data['2017-01':'2017-11'],type='candle',mav=(20),volume=True)

# %%
mpf.plot(data['2017-01':'2017-11'],type='candle',mav=(20),style='yahoo',volume=True)
